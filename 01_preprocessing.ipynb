# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Data location

# %%
from pathlib import Path

DATA_DIR = Path("C:/Users/hugoc/Downloads/GreySealData/GreySealData")

assert DATA_DIR.exists(), "GreySealData directory not found"

# List top-level contents of GreySealData
list(DATA_DIR.iterdir())
# Out:
# [WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/additional-grey-seal-data'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Guttural rupe'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Moan'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B')]

# %% [markdown]
# ## Loading annotations

# %%
import pandas as pd

# Directory for Rupes A and B calls
RUPES_DIR = DATA_DIR / "Rupes A and B"

# Inspect directory contents
list(RUPES_DIR.iterdir())
# Out:
# [WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210806110002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210806110002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210807110002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210807110002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210808110002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210808110002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210809120002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210809120002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210811140002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210811140002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210811190002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210811190002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210814160002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210814160002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210823180002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210823180002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210825190002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210825190002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210827200002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210827200002.wav'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210908180002.Table.1.selections.txt'),
#  WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210908180002.wav')]

# %%
# Load one annotation file
ann_path = sorted(RUPES_DIR.glob("*.Table.1.selections.txt"))[0]
print("Annotation file:", ann_path.name)

df = pd.read_csv(ann_path, sep="\t")

df.head()
# Out:
# Annotation file: 5713.210806110002.Table.1.selections.txt
#    Selection           View  Channel  Begin Time (s)  End Time (s)  \
# 0          1  Spectrogram 1        1       13.433865     13.703649
# 1          2  Spectrogram 1        1       26.072555     26.283886
# 2          3  Spectrogram 1        1       53.382769     53.528888
# 3          4  Spectrogram 1        1       65.997665     66.110075
# 4          5  Spectrogram 1        1       81.003161     81.266117
#
#    Low Freq (Hz)  High Freq (Hz)  Delta Time (s)  Delta Freq (Hz)  \
# 0         53.191         324.361          0.2698          271.170
# 1         53.191         376.259          0.2113          323.068
# 2         66.489         478.723          0.1461          412.234
# 3         59.347         415.430          0.1124          356.083
# 4         59.347         376.259          0.2630          316.912
#
#    Avg Power Density (dB FS/Hz) Annotation
# 0                        -79.66     Rupe B
# 1                        -84.94     Rupe B
# 2                        -89.26     Rupe A
# 3                        -86.86     Rupe A
# 4                        -82.32     Rupe B

# %%
df["Annotation"].value_counts()
# Out:
# Annotation
# Rupe A      73
# Rupe B      53
# Type 4 A    10
# Rupe C       4
# Name: count, dtype: int64

# %%
wav_path = ann_path.name.replace(".Table.1.selections.txt", ".wav")
wav_path = RUPES_DIR / wav_path

wav_path, wav_path.exists()
# Out:
# (WindowsPath('C:/Users/hugoc/Downloads/GreySealData/GreySealData/Rupes A and B/5713.210806110002.wav'),
#  True)

# %% [markdown]
# ## Spectrogram generation

# %% [markdown]
# ## Next steps
