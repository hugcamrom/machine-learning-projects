# %% [markdown]
# ## Introduction
#
# ## Data location
#
# ## Loading annotations
#
# ## Spectrogram generation
#
# ## Next steps

# %% [markdown]
# ## Data location

# %%
from pathlib import Path

DATA_DIR = Path("C:/Users/hugoc/Downloads/GreySealData")

assert DATA_DIR.exists(), "GreySealData directory not found"
